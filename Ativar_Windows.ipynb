# %% [markdown]
# # **Ativar Windows**

# %% [markdown]
# - 1. baixe o WINDOWS PRO , pode ser o original mesmo
# - 2. na hora da solicitação da chave, pule a etapa, informado que não tem uma chave

# %% [markdown]
# ## **Ativação Windows**
#
# Depois do Pc formatado abra o powershell e digite o seguinte comando
#
# ```shell
# irm https://massgrave.dev/get | iex

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# * irá pedir permissão , selecione `permitir`
# * após isso ira abrir o cmd
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - escolha uma numeração do menu `use o numerio abaixo das teclas F1, F2 ...`
#
# - Escolha a opção `1`
#
# - e pronto o windows será ativado
#
# - para verificar , clique na BANDEIRA DO WINDOWS > CONFIGURAÇÔES > ATUALIZAÇÂO E SEGURANÇA > ATIVAÇÂO
#
# ![image.png](attachment:image.png)
