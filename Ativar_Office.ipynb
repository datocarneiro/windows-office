# %% [markdown]
# # **Ativar Office 365**

# %% [markdown]
# - baixar o Office 365 pode ser o original se conseguir
# - no Diretorio tem um executavel para instalação

# %% [markdown]
# - Após a instalação, abra o power shell e digite o seguinte comando
#
# ```shell
# irm https://massgrave.dev/get | iex

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Irá solicitar permissão, clique em permitir
# - apos permitir ira abrie o cmd

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - escolha um numero usando o numero  que ha abaixo das teclas F1, F2 ...

# %% [markdown]
# Escolha uma das opção do menu que aparece
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Ativação Office**
#
# - para o office 365, use a opção `2`
# - pronto o office esta ativado
